# %%
print("Hello")
# Out:
# Hello

# %%
print("j")
# Out:
# j

# %%
import pandas as pd

# %%
df = pd.read_csv("sales_data.csv")

# %%
df
# Out:
#    order_id  order_date  customer_id         product     category  quantity  \
# 0      1001  2025-01-01          501  Wireless Mouse  Electronics         2
# 1      1002  2025-01-02          502        Notebook   Stationery         5
# 2      1003  2025-01-02          503       USB Cable  Electronics         1
# 3      1004  2025-01-03          504      Coffee Mug         Home         3
# 4      1005  2025-01-03          505    Laptop Stand  Electronics         1
# 5      1006  2025-01-04          506             Pen   Stationery        10
# 6      1007  2025-01-04          507        Notebook   Stationery         2
# 7      1008  2025-01-05          508      Headphones  Electronics         1
# 8      1009  2025-01-05          509      Coffee Mug         Home         1
# 9      1010  2025-01-06          510  Wireless Mouse  Electronics         1
#
#    price       city payment_method
# 0     15     Lahore    Credit Card
# 1      2    Karachi           Cash
# ...

# %%
df.head()
# Out:
#    order_id  order_date  customer_id         product     category  quantity  \
# 0      1001  2025-01-01          501  Wireless Mouse  Electronics         2
# 1      1002  2025-01-02          502        Notebook   Stationery         5
# 2      1003  2025-01-02          503       USB Cable  Electronics         1
# 3      1004  2025-01-03          504      Coffee Mug         Home         3
# 4      1005  2025-01-03          505    Laptop Stand  Electronics         1
#
#    price       city payment_method
# 0     15     Lahore    Credit Card
# 1      2    Karachi           Cash
# 2      5  Islamabad     Debit Card
# 3      6     Lahore    Credit Card
# 4     25    Karachi    Credit Card

# %%
df["Total Amount"] = df["quantity"] * df['price']

# %%
df
# Out:
#    order_id  order_date  customer_id         product     category  quantity  \
# 0      1001  2025-01-01          501  Wireless Mouse  Electronics         2
# 1      1002  2025-01-02          502        Notebook   Stationery         5
# 2      1003  2025-01-02          503       USB Cable  Electronics         1
# 3      1004  2025-01-03          504      Coffee Mug         Home         3
# 4      1005  2025-01-03          505    Laptop Stand  Electronics         1
# 5      1006  2025-01-04          506             Pen   Stationery        10
# 6      1007  2025-01-04          507        Notebook   Stationery         2
# 7      1008  2025-01-05          508      Headphones  Electronics         1
# 8      1009  2025-01-05          509      Coffee Mug         Home         1
# 9      1010  2025-01-06          510  Wireless Mouse  Electronics         1
#
#    price       city payment_method  Total Amount
# 0     15     Lahore    Credit Card            30
# ...

# %%
sum = df['Total Amount'].sum()

# %%
sum
# Out:
# np.int64(153)

# %%
df
# Out:
#    order_id  order_date  customer_id         product     category  quantity  \
# 0      1001  2025-01-01          501  Wireless Mouse  Electronics         2
# 1      1002  2025-01-02          502        Notebook   Stationery         5
# 2      1003  2025-01-02          503       USB Cable  Electronics         1
# 3      1004  2025-01-03          504      Coffee Mug         Home         3
# 4      1005  2025-01-03          505    Laptop Stand  Electronics         1
# 5      1006  2025-01-04          506             Pen   Stationery        10
# 6      1007  2025-01-04          507        Notebook   Stationery         2
# 7      1008  2025-01-05          508      Headphones  Electronics         1
# 8      1009  2025-01-05          509      Coffee Mug         Home         1
# 9      1010  2025-01-06          510  Wireless Mouse  Electronics         1
#
#    price       city payment_method  Total Amount  Revenue
# 0     15     Lahore    Credit Card            30      153
# ...

# %%
df['city'].value_counts()
# Out:
# city
# Lahore       4
# Karachi      3
# Islamabad    3
# Name: count, dtype: int64

# %%
df['city']
# Out:
# 0       Lahore
# 1      Karachi
# 2    Islamabad
# 3       Lahore
# 4      Karachi
# 5    Islamabad
# 6       Lahore
# 7      Karachi
# 8    Islamabad
# 9       Lahore
# Name: city, dtype: object

# %%
df['city'].value_counts()
# Out:
# city
# Lahore       4
# Karachi      3
# Islamabad    3
# Name: count, dtype: int64

# %%
df.groupby('category')['Total Amount'].sum()
# Out:
# category
# Electronics    105
# Home            24
# Stationery      24
# Name: Total Amount, dtype: int64

# %%
df.groupby('product')['quantity'].max().sort_values(ascending=False)
# Out:
# product
# Pen               10
# Notebook           5
# Coffee Mug         3
# Wireless Mouse     2
# Headphones         1
# Laptop Stand       1
# USB Cable          1
# Name: quantity, dtype: int64

# %%
df
# Out:
#    order_id  order_date  customer_id         product     category  quantity  \
# 0      1001  2025-01-01          501  Wireless Mouse  Electronics         2
# 1      1002  2025-01-02          502        Notebook   Stationery         5
# 2      1003  2025-01-02          503       USB Cable  Electronics         1
# 3      1004  2025-01-03          504      Coffee Mug         Home         3
# 4      1005  2025-01-03          505    Laptop Stand  Electronics         1
# 5      1006  2025-01-04          506             Pen   Stationery        10
# 6      1007  2025-01-04          507        Notebook   Stationery         2
# 7      1008  2025-01-05          508      Headphones  Electronics         1
# 8      1009  2025-01-05          509      Coffee Mug         Home         1
# 9      1010  2025-01-06          510  Wireless Mouse  Electronics         1
#
#    price       city payment_method  Total Amount  Revenue
# 0     15     Lahore    Credit Card            30      153
# ...

# %%
df.dropna('Revenue')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 df.dropna('Revenue')
#
# TypeError: DataFrame.dropna() takes 1 positional argument but 2 were given

# %%
df['payment_method'].value_counts()
# Out:
# payment_method
# Credit Card    5
# Cash           3
# Debit Card     2
# Name: count, dtype: int64

# %%
df.groupby('city')['Total Amount'].sum()
# Out:
# city
# Islamabad    21
# Karachi      65
# Lahore       67
# Name: Total Amount, dtype: int64

# %%
df.groupby('city')['Total Amount'].sum().sort_values(ascending = False)
# Out:
# city
# Lahore       67
# Karachi      65
# Islamabad    21
# Name: Total Amount, dtype: int64

# %%
df
# Out:
#    order_id  order_date  customer_id         product     category  quantity  \
# 0      1001  2025-01-01          501  Wireless Mouse  Electronics         2
# 1      1002  2025-01-02          502        Notebook   Stationery         5
# 2      1003  2025-01-02          503       USB Cable  Electronics         1
# 3      1004  2025-01-03          504      Coffee Mug         Home         3
# 4      1005  2025-01-03          505    Laptop Stand  Electronics         1
# 5      1006  2025-01-04          506             Pen   Stationery        10
# 6      1007  2025-01-04          507        Notebook   Stationery         2
# 7      1008  2025-01-05          508      Headphones  Electronics         1
# 8      1009  2025-01-05          509      Coffee Mug         Home         1
# 9      1010  2025-01-06          510  Wireless Mouse  Electronics         1
#
#    price       city payment_method  Total Amount  Revenue
# 0     15     Lahore    Credit Card            30      153
# ...

# %%
df['order_date'] = pd.to_datetime(df['order_date'])

# %%
df['order_date']
# Out:
# 0   2025-01-01
# 1   2025-01-02
# 2   2025-01-02
# 3   2025-01-03
# 4   2025-01-03
# 5   2025-01-04
# 6   2025-01-04
# 7   2025-01-05
# 8   2025-01-05
# 9   2025-01-06
# Name: order_date, dtype: datetime64[ns]

# %%
df.groupby("order_date")["Total Amount"].sum()
# Out:
# order_date
# 2025-01-01    30
# 2025-01-02    15
# 2025-01-03    43
# 2025-01-04    14
# 2025-01-05    36
# 2025-01-06    15
# Name: Total Amount, dtype: int64

# %%
df.groupby("customer_id")["Total Amount"].sum()
# Out:
# customer_id
# 501    30
# 502    10
# 503     5
# 504    18
# 505    25
# 506    10
# 507     4
# 508    30
# 509     6
# 510    15
# Name: Total Amount, dtype: int64

# %%
df
# Out:
#    order_id order_date  customer_id         product     category  quantity  \
# 0      1001 2025-01-01          501  Wireless Mouse  Electronics         2
# 1      1002 2025-01-02          502        Notebook   Stationery         5
# 2      1003 2025-01-02          503       USB Cable  Electronics         1
# 3      1004 2025-01-03          504      Coffee Mug         Home         3
# 4      1005 2025-01-03          505    Laptop Stand  Electronics         1
# 5      1006 2025-01-04          506             Pen   Stationery        10
# 6      1007 2025-01-04          507        Notebook   Stationery         2
# 7      1008 2025-01-05          508      Headphones  Electronics         1
# 8      1009 2025-01-05          509      Coffee Mug         Home         1
# 9      1010 2025-01-06          510  Wireless Mouse  Electronics         1
#
#    price       city payment_method  Total Amount  Revenue
# 0     15     Lahore    Credit Card            30      153
# ...

# %%
df["customer_id"].value_counts()
# Out:
# customer_id
# 501    1
# 502    1
# 503    1
# 504    1
# 505    1
# 506    1
# 507    1
# 508    1
# 509    1
# 510    1
# Name: count, dtype: int64

# %%
df['customer_id'].duplicated().isnull()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
# Name: customer_id, dtype: bool

# %%
df
# Out:
#    order_id order_date  customer_id         product     category  quantity  \
# 0      1001 2025-01-01          501  Wireless Mouse  Electronics         2
# 1      1002 2025-01-02          502        Notebook   Stationery         5
# 2      1003 2025-01-02          503       USB Cable  Electronics         1
# 3      1004 2025-01-03          504      Coffee Mug         Home         3
# 4      1005 2025-01-03          505    Laptop Stand  Electronics         1
# 5      1006 2025-01-04          506             Pen   Stationery        10
# 6      1007 2025-01-04          507        Notebook   Stationery         2
# 7      1008 2025-01-05          508      Headphones  Electronics         1
# 8      1009 2025-01-05          509      Coffee Mug         Home         1
# 9      1010 2025-01-06          510  Wireless Mouse  Electronics         1
#
#    price       city payment_method  Total Amount  Revenue
# 0     15     Lahore    Credit Card            30      153
# ...

# %%
df.to_csv('clean_sales_data.csv', index=False)

# %%
df.drop(columns = ['Revenue'])
# Out:
#    order_id order_date  customer_id         product     category  quantity  \
# 0      1001 2025-01-01          501  Wireless Mouse  Electronics         2
# 1      1002 2025-01-02          502        Notebook   Stationery         5
# 2      1003 2025-01-02          503       USB Cable  Electronics         1
# 3      1004 2025-01-03          504      Coffee Mug         Home         3
# 4      1005 2025-01-03          505    Laptop Stand  Electronics         1
# 5      1006 2025-01-04          506             Pen   Stationery        10
# 6      1007 2025-01-04          507        Notebook   Stationery         2
# 7      1008 2025-01-05          508      Headphones  Electronics         1
# 8      1009 2025-01-05          509      Coffee Mug         Home         1
# 9      1010 2025-01-06          510  Wireless Mouse  Electronics         1
#
#    price       city payment_method  Total Amount
# 0     15     Lahore    Credit Card            30
# ...
